# %% [markdown]
# # Week 17, Lecture 01 CodeAlong
# - Coefficients & Feature Importance

# %% [markdown]
# ## Lesson Objectives

# %% [markdown]
# - By the end of this lesson, students will be able to:
#     - Extract feature names from sklearn v1.1 objects
#     - Extract and visualize coefficients
#     - Save models to a joblib file

# %% [markdown]
# ### Life Expectancy

# %% [markdown]
# > Task Inspired by: https://medium.com/@shanzehhaji/using-a-linear-regression-model-to-predict-life-expectancy-de3aef66ac21
#
# - Kaggle Dataset on Life Expectancy:
#     - https://www.kaggle.com/datasets/kumarajarshi/life-expectancy-who

# %%
## Our standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as miss

## Preprocessing tools
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

## Models & evaluation metrics
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import joblib

## setting random state for reproducibility
SEED = 321
np.random.seed(SEED)
## Matplotlib style
fav_style = ('ggplot','tableau-colorblind10')
fav_context  ={'context':'notebook', 'font_scale':1.1}
plt.style.use(fav_style)
sns.set_context(**fav_context)
plt.rcParams['savefig.transparent'] = False
plt.rcParams['savefig.bbox'] = 'tight'

# %%
## Importing Custom Functions
# %load_ext autoreload
# %autoreload 2
from CODE import data_enrichment as de

# %%
import pandas as pd
df = pd.read_csv("Data/Life Expectancy Data.csv")
df.info()
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
#
# [3 rows x 22 columns]

# %%
# clean extra spaces
df.columns = df.columns.str.strip()
df
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2933  ...   67.0               7.13        65.0      33.6  454.366654
# 2934  ...    7.0               6.52        68.0      36.7  453.351155
# 2935  ...   73.0               6.53        71.0      39.8   57.348340
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
# 2937  ...   78.0               7.10        78.0      43.5  547.358878
#
#       Population  thinness  1-19 years  thinness 5-9 years  \
# 0     33736494.0                  17.2                17.3
# 1       327582.0                  17.5                17.5
# 2     31731688.0                  17.7                17.7
# 3      3696958.0                  17.9                18.0
# 4      2978599.0                  18.2                18.2
# ...          ...                   ...                 ...
# 2933  12777511.0                   9.4                 9.4
# 2934  12633897.0                   9.8                 9.9
# 2935    125525.0                   1.2                 1.3
# 2936  12366165.0                   1.6                 1.7
# 2937  12222251.0                  11.0                11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
pd.set_option('display.max_columns',0)
df
# Out:
#           Country  Year  ... Income composition of resources  Schooling
# 0     Afghanistan  2015  ...                           0.479       10.1
# 1     Afghanistan  2014  ...                           0.476       10.0
# 2     Afghanistan  2013  ...                           0.470        9.9
# 3     Afghanistan  2012  ...                           0.463        9.8
# 4     Afghanistan  2011  ...                           0.454        9.5
# ...           ...   ...  ...                             ...        ...
# 2933     Zimbabwe  2004  ...                           0.407        9.2
# 2934     Zimbabwe  2003  ...                           0.418        9.5
# 2935     Zimbabwe  2002  ...                           0.427       10.0
# 2936     Zimbabwe  2001  ...                           0.427        9.8
# 2937     Zimbabwe  2000  ...                           0.434        9.8
#
# [2938 rows x 22 columns]

# %% [markdown]
# ## EDA

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
miss.matrix(df)
# Out:
# <AxesSubplot: >

# %% [markdown]
# > Can't have null values for the target!

# %%
# drop null values ONLY FROM TARGET
df = df.dropna(subset=['Life expectancy'])

# %%
target = 'Life expectancy'

grid_spec = {'height_ratios':[0.8,0.2]}
fig, axes = plt.subplots(nrows=2, figsize=(6,5), gridspec_kw=grid_spec)

sns.histplot(data=df, x=target,ax=axes[0])
sns.boxplot(data=df, x=target, ax=axes[1]);

# %% [markdown]
# ## Preprocessing (with Sklearn v1.1+)

# %%
# Run the following command on your local computer to check the version of sklearn
import sklearn
# !python --version
print(f"sklearn version: {sklearn.__version__}")
# Out:
# Python 3.9.15
# sklearn version: 1.1.3

# %%
# ### Train Test Split
## Make x and y variables
target = "Life expectancy"
drop_feats = []

y = df[target].copy()
X = df.drop(columns=[target, *drop_feats]).copy()

## train-test-split with random state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=SEED)
X_train.head(3)
# Out:
#           Country  Year  ... Income composition of resources  Schooling
# 2414  South Sudan  2010  ...                           0.000        0.0
# 1576       Malawi  2009  ...                           0.415        9.9
# 2559   Tajikistan  2009  ...                           0.601       11.1
#
# [3 rows x 21 columns]

# %%
## Make numeric preprocessing pipeline
num_sel = make_column_selector(dtype_include='number')
num_pipe = make_pipeline(SimpleImputer(strategy='mean'))
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer())])

# %%
## Make categorical preprocessing pipeline
cat_sel = make_column_selector(dtype_include='object')
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(handle_unknown='ignore', sparse=False))

# %%
## make the preprocessing column transformer
preprocessor = make_column_transformer((num_pipe, num_sel),
                                       (cat_pipe,cat_sel),)
preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000002A4504A0C40>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000002A4504A05B0>)])

# %% [markdown]
# ### Make X_train_df and X_test_df, dataframe verisons of processed X_train/X_test.

# %%
preprocessor.fit(X_train)
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_train.index)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_test.index)
display(X_train_df)
# Out:
#       pipeline-1__Year  ...  pipeline-2__Status_Developing
# 2414            2010.0  ...                            1.0
# 1576            2009.0  ...                            1.0
# 2559            2009.0  ...                            1.0
# 1524            2013.0  ...                            0.0
# 33              2014.0  ...                            1.0
# ...                ...  ...                            ...
# 1427            2014.0  ...                            1.0
# 1838            2006.0  ...                            0.0
# 2857            2000.0  ...                            1.0
# 124             2003.0  ...                            0.0
# 2595            2005.0  ...                            1.0
#
# [2196 rows x 204 columns]

# %% [markdown]
# > #### Q: What's up with the feature names? What are we seeing?

# %% [markdown]
# ### Get Features Names + Verbose Feature Names Out

# %%
## make the preprocessing column transformer WITH CORRECT ARGS!
preprocessor = make_column_transformer((num_pipe, num_sel),
                                       (cat_pipe,cat_sel),
                                      verbose_feature_names_out=False)
preprocessor.fit(X_train)
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_train.index)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_test.index)
display(X_train_df)
# Out:
#         Year  Adult Mortality  ...  Status_Developed  Status_Developing
# 2414  2010.0            359.0  ...               0.0                1.0
# 1576  2009.0            491.0  ...               0.0                1.0
# 2559  2009.0            174.0  ...               0.0                1.0
# 1524  2013.0            178.0  ...               1.0                0.0
# 33    2014.0             11.0  ...               0.0                1.0
# ...      ...              ...  ...               ...                ...
# 1427  2014.0            199.0  ...               0.0                1.0
# 1838  2006.0             71.0  ...               1.0                0.0
# 2857  2000.0             18.0  ...               0.0                1.0
# 124   2003.0             71.0  ...               1.0                0.0
# 2595  2005.0             12.0  ...               0.0                1.0
#
# [2196 rows x 204 columns]

# %% [markdown]
# # Modeling - Linear Regression

# %%
def evaluate_regression(model, X_train,y_train, X_test, y_test,for_slides=True): 
    """Evaluates a scikit learn regression model using r-squared and RMSE
    FOR SLIDES VERS DOES MULTIPLE PRINT STATEMENTS FOR VERTICAL DISPLAY OF INFO"""
    
    ## Training Data
    y_pred_train = model.predict(X_train)
    r2_train = metrics.r2_score(y_train, y_pred_train)
    rmse_train = metrics.mean_squared_error(y_train, y_pred_train, 
                                            squared=False)
    mae_train = metrics.mean_absolute_error(y_train, y_pred_train)
    

    ## Test Data
    y_pred_test = model.predict(X_test)
    r2_test = metrics.r2_score(y_test, y_pred_test)
    rmse_test = metrics.mean_squared_error(y_test, y_pred_test, 
                                            squared=False)
    mae_test = metrics.mean_absolute_error(y_test, y_pred_test)
    
    if for_slides:
        df_version =[['Split','R^2','MAE','RMSE']]
        df_version.append(['Train',r2_train, mae_train, rmse_train])
        df_version.append(['Test',r2_test, mae_test, rmse_test])
        df_results = pd.DataFrame(df_version[1:], columns=df_version[0])
        df_results = df_results.round(2)
        display(df_results.style.hide(axis='index').format(precision=2, thousands=','))
        
    else: 
        print(f"Training Data:\tR^2 = {r2_train:,.2f}\tRMSE = {rmse_train:,.2f}\tMAE = {mae_train:,.2f}")
        print(f"Test Data:\tR^2 = {r2_test:,.2f}\tRMSE = {rmse_test:,.2f}\tMAE = {mae_test:,.2f}")

# %% [markdown]
# ## Model 1: Baseline LinReg

# %%
from sklearn.linear_model import LinearRegression
lin_reg= LinearRegression()
lin_reg.fit(X_train_df,y_train)
evaluate_regression(lin_reg, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ac1e">
#   <thead>
#     <tr>
#       <th id="T_1ac1e_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_1ac1e_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_1ac1e_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_1ac1e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1ac1e_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_1ac1e_row0_col1" class="data row0 col1" >0.96</td>
#       <td id="T_1ac1e_row0_col2" class="data row0 col2" >1.14</td>
#       <td id="T_1ac1e_row0_col3" class="data row0 col3" >1.83</td>
#     </tr>
#     <tr>
#       <td id="T_1ac1e_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_1ac1e_row1_col1" class="data row1 col1" >0.96</td>
#       <td id="T_1ac1e_row1_col2" class="data row1 col2" >1.20</td>
#       <td id="T_1ac1e_row1_col3" class="data row1 col3" >1.88</td>
#     </tr>
#   </tbody>
# </table>

# %%
de.plot_residuals(lin_reg, X_test_df,y_test)

# %% [markdown]
# ### Extracting and Visualizing Coefficients

# %% [markdown]
# #### Extracting Coefficients

# %%
## access the .coef_ 
# lin_reg.coef_

# %%
## Intercept
# lin_reg.intercept_

# %%
# ## Saving the coefficients
# coeffs = pd.Series(lin_reg.coef_, index= lin_reg.feature_names_in_)
# coeffs.loc['intercept'] = lin_reg.intercept_
# coeffs

# %% [markdown]
# #### def `get_coefficients`

# %%
def get_coefficients(lin_reg):
    coeffs = pd.Series(lin_reg.coef_, index= lin_reg.feature_names_in_)
    coeffs.loc['intercept'] = lin_reg.intercept_
    return coeffs

# %%
coeffs = get_coefficients(lin_reg)
coeffs
# Out:
# Year                        0.265644
# Adult Mortality            -0.002424
# infant deaths               0.109358
# Alcohol                    -0.064367
# percentage expenditure      0.000154
#                              ...
# Country_Zambia             -9.018217
# Country_Zimbabwe           -8.385612
# Status_Developed            5.307128
# Status_Developing          -5.307119
# intercept                -461.245541
# Length: 205, dtype: float64

# %%
## formatting numbers to not use , thousands sep, and 4 digits floats
pd.set_option('display.float_format',lambda x: f"{x:,.4f}")
pd.set_option('display.max_rows', None)

# %%
coeffs.sort_values()
# Out:
# intercept                                                      -461.2455
# Country_Sierra Leone                                            -19.3439
# Country_Côte d'Ivoire                                           -15.4878
# Country_Central African Republic                                -15.2399
# Country_Angola                                                  -15.2160
# Country_Chad                                                    -13.7055
# Country_Somalia                                                 -12.4401
# Country_Malawi                                                  -11.4993
# Country_Lesotho                                                 -11.3403
# Country_Guinea-Bissau                                           -10.5861
# Country_South Sudan                                             -10.5449
# Country_Burundi                                                 -10.4404
# Country_Cameroon                                                -10.1861
# Country_Guinea                                                  -10.1712
# Country_Democratic Republic of the Congo                        -10.1366
# Country_Mali                                                     -9.9653
# Country_Equatorial Guinea                                        -9.7840
# Country_Togo                                                     -9.7698
# Country_Mozambique                                               -9.7641
# Country_Benin                                                    -9.2593
# Country_Afghanistan                                              -9.1717
# Country_Burkina Faso                                             -9.1021
# Country_Zambia                                                   -9.0182
# Country_Liberia                                                  -8.9318
# Country_Zimbabwe                                                 -8.3856
# Country_United Republic of Tanzania                              -7.7254
# Country_Gambia                                                   -7.5350
# Country_Congo                                                    -7.4814
# Country_Niger                                                    -7.3244
# Country_Rwanda                                                   -7.2113
# Country_Uganda                                                   -7.0310
# Country_Eritrea                                                  -6.6634
# Country_Kenya                                                    -6.5444
# Country_Haiti                                                    -6.4665
# Country_Comoros                                                  -6.2642
# Country_Botswana                                                 -6.1271
# Country_Romania                                                  -6.0393
# Country_Lithuania                                                -6.0133
# Country_Pakistan                                                 -5.9946
# Country_Ghana                                                    -5.6855
# Country_Swaziland                                                -5.6651
# Country_Bulgaria                                                 -5.5721
# Status_Developing                                                -5.3071
# Country_Papua New Guinea                                         -5.2930
# Country_Lao People's Democratic Republic                         -5.1727
# Country_Djibouti                                                 -4.9420
# Country_Hungary                                                  -4.8169
# Country_Mauritania                                               -4.7685
# Country_Latvia                                                   -4.5692
# Country_Senegal                                                  -4.4294
# Country_Sudan                                                    -4.3962
# Country_Madagascar                                               -4.2632
# Country_India                                                    -4.0935
# Country_South Africa                                             -4.0866
# Country_Myanmar                                                  -3.9183
# Country_Ethiopia                                                 -3.8403
# Country_Timor-Leste                                              -3.7631
# Country_Cambodia                                                 -3.7429
# Country_Slovakia                                                 -3.7338
# Country_Yemen                                                    -3.6776
# Country_Turkmenistan                                             -3.2145
# Country_Poland                                                   -3.1889
# Country_Namibia                                                  -3.1133
# Country_Kiribati                                                 -3.0362
# Country_Croatia                                                  -2.6742
# Country_Sao Tome and Principe                                    -2.6345
# Country_Gabon                                                    -2.6268
# Country_Bhutan                                                   -2.4620
# Country_Mongolia                                                 -2.2746
# Country_Nepal                                                    -2.1496
# Country_Indonesia                                                -1.9754
# Country_Nigeria                                                  -1.8029
# Country_Guyana                                                   -1.7270
# Country_Tajikistan                                               -1.5385
# Country_Czechia                                                  -1.3900
# Country_Kazakhstan                                               -1.3704
# Country_Philippines                                              -0.5655
# Country_United States of America                                 -0.4879
# Country_Uzbekistan                                               -0.4015
# Country_Bolivia (Plurinational State of)                         -0.3605
# HIV/AIDS                                                         -0.3205
# Country_Russian Federation                                       -0.2607
# Income composition of resources                                  -0.2243
# under-five deaths                                                -0.0826
# Alcohol                                                          -0.0644
# Total expenditure                                                -0.0239
# Country_Slovenia                                                 -0.0211
# Hepatitis B                                                      -0.0046
# BMI                                                              -0.0026
# Adult Mortality                                                  -0.0024
# GDP                                                              -0.0000
# Measles                                                          -0.0000
# Population                                                        0.0000
# percentage expenditure                                            0.0002
# Diphtheria                                                        0.0049
# Country_Denmark                                                   0.0056
# Polio                                                             0.0057
# Country_Solomon Islands                                           0.0109
# thinness 5-9 years                                                0.0162
# thinness  1-19 years                                              0.0256
# Country_Fiji                                                      0.0739
# infant deaths                                                     0.1094
# Schooling                                                         0.1463
# Year                                                              0.2656
# Country_Micronesia (Federated States of)                          0.5334
# Country_Bangladesh                                                0.8295
# Country_Belgium                                                   1.0001
# Country_Cyprus                                                    1.0020
# Country_Kyrgyzstan                                                1.1735
# Country_Democratic People's Republic of Korea                     1.1787
# Country_Ireland                                                   1.3642
# Country_Belize                                                    1.3909
# Country_Portugal                                                  1.4045
# Country_New Zealand                                               1.5795
# Country_Germany                                                   1.6910
# Country_Malta                                                     1.7526
# Country_Ukraine                                                   1.8411
# Country_Netherlands                                               1.8682
# Country_Belarus                                                   2.0765
# Country_Norway                                                    2.1011
# Country_Syrian Arab Republic                                      2.1099
# Country_Luxembourg                                                2.1540
# Country_Australia                                                 2.2835
# Country_Sweden                                                    2.3242
# Country_Singapore                                                 2.3691
# Country_Suriname                                                  2.4562
# Country_United Kingdom of Great Britain and Northern Ireland      2.4744
# Country_Switzerland                                               2.6197
# Country_Azerbaijan                                                2.6223
# Country_Iraq                                                      2.6481
# Country_Republic of Moldova                                       2.7691
# Country_Egypt                                                     2.8309
# Country_Iceland                                                   2.9603
# Country_Libya                                                     3.0206
# Country_Austria                                                   3.0797
# Country_Trinidad and Tobago                                       3.1004
# Country_China                                                     3.1433
# Country_Spain                                                     3.2163
# Country_Italy                                                     3.2607
# Country_Japan                                                     3.3030
# Country_Vanuatu                                                   3.5317
# Country_El Salvador                                               3.5775
# Country_Morocco                                                   3.6025
# Country_Sri Lanka                                                 3.9134
# Country_Brazil                                                    3.9213
# Country_Mauritius                                                 4.1302
# Country_Guatemala                                                 4.2767
# Country_Jordan                                                    4.2884
# Country_Tonga                                                     4.3100
# Country_Saudi Arabia                                              4.3625
# Country_Seychelles                                                4.4281
# Country_Cabo Verde                                                4.5222
# Country_Thailand                                                  4.5424
# Country_Algeria                                                   4.5999
# Country_Paraguay                                                  4.6176
# Country_Iran (Islamic Republic of)                                4.7422
# Country_Grenada                                                   4.8194
# Country_Nicaragua                                                 4.9773
# Country_Colombia                                                  4.9792
# Country_Dominican Republic                                        5.0158
# Country_Saint Vincent and the Grenadines                          5.0846
# Country_Turkey                                                    5.1796
# Country_Malaysia                                                  5.1907
# Country_Honduras                                                  5.2252
# Country_Armenia                                                   5.2406
# Status_Developed                                                  5.3071
# Country_Peru                                                      5.4266
# Country_Venezuela (Bolivarian Republic of)                        5.4748
# Country_Kuwait                                                    5.5087
# Country_Tunisia                                                   5.5193
# Country_Georgia                                                   5.5514
# Country_Lebanon                                                   5.5826
# Country_The former Yugoslav republic of Macedonia                 5.6843
# Country_Serbia                                                    5.9160
# Country_Viet Nam                                                  5.9871
# Country_Saint Lucia                                               6.0360
# Country_Barbados                                                  6.0630
# Country_Oman                                                      6.0924
# Country_Samoa                                                     6.1060
# Country_Maldives                                                  6.2194
# Country_Montenegro                                                6.2765
# Country_Argentina                                                 6.3523
# Country_Jamaica                                                   6.4010
# Country_Ecuador                                                   6.5222
# Country_Bahamas                                                   6.6436
# Country_Estonia                                                   6.7086
# Country_Albania                                                   6.7894
# Country_Bahrain                                                   6.8303
# Country_Mexico                                                    7.0508
# Country_United Arab Emirates                                      7.1877
# Country_Brunei Darussalam                                         7.4862
# Country_Antigua and Barbuda                                       7.5314
# Country_Bosnia and Herzegovina                                    7.6179
# Country_Uruguay                                                   7.8886
# Country_Panama                                                    8.5552
# Country_Qatar                                                     8.7526
# Country_Cuba                                                      9.0039
# Country_Costa Rica                                               10.2361
# Country_Chile                                                    10.9669
# Country_Finland                                                  11.8384
# Country_Republic of Korea                                        12.7644
# Country_Israel                                                   12.7908
# Country_Canada                                                   13.1336
# Country_France                                                   13.1650
# Country_Greece                                                   13.2538
# dtype: float64

# %% [markdown]
# ### Visualizing

# %% [markdown]
# #### **Q: How can we handle this many coefficients in our viz?**
#
# - Some options include:
#     - Only plot most the N most positive and N most negative.
#     - Separate out OHE countries into a separate graph.
#
#
# - Let's try the second option: separating the OHE countries.

# %%
## Get a list of all of the ohe columsn
country_feats = [c for c in X_train_df.columns if c.startswith('Country')]
len(country_feats)
# Out:
# 183

# %%
## Plot country ceoffs
ax = coeffs[country_feats].sort_values().plot(kind='barh', figsize=(8,26))
ax.axvline(0, color='k')
ax.set(xlabel='Life Expectancy', title="Coefficients - Countries");

# %%
## Plot everything but countries
ax = coeffs.drop(country_feats).sort_values().plot(kind='barh')#, figsize=(8,26))
ax.axvline(0)
ax.set(xlabel='Life Expectancy', title="Coefficients - Without Countries");

# %% [markdown]
# > ***Q: What do we notice about our non-country coefficients? Is there anything odd that would be difficult to a stakeholder?***

# %% [markdown]
# - What would we get if we didn't include an intercept?

# %% [markdown]
# ## Model #2 - No Intercept

# %%
lin_reg_noint= LinearRegression(fit_intercept=False)
lin_reg_noint.fit(X_train_df,y_train)
evaluate_regression(lin_reg_noint, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_14004">
#   <thead>
#     <tr>
#       <th id="T_14004_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_14004_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_14004_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_14004_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_14004_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_14004_row0_col1" class="data row0 col1" >0.96</td>
#       <td id="T_14004_row0_col2" class="data row0 col2" >1.14</td>
#       <td id="T_14004_row0_col3" class="data row0 col3" >1.83</td>
#     </tr>
#     <tr>
#       <td id="T_14004_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_14004_row1_col1" class="data row1 col1" >0.96</td>
#       <td id="T_14004_row1_col2" class="data row1 col2" >1.20</td>
#       <td id="T_14004_row1_col3" class="data row1 col3" >1.88</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > Notice the model's performance is the same

# %%
de.plot_residuals(lin_reg_noint, X_test_df,y_test)

# %%
coeffs_noint = get_coefficients(lin_reg_noint)
coeffs_noint
# Out:
# Year                                                                0.2656
# Adult Mortality                                                    -0.0024
# infant deaths                                                       0.1094
# Alcohol                                                            -0.0644
# percentage expenditure                                              0.0002
# Hepatitis B                                                        -0.0046
# Measles                                                            -0.0000
# BMI                                                                -0.0026
# under-five deaths                                                  -0.0827
# Polio                                                               0.0057
# Total expenditure                                                  -0.0238
# Diphtheria                                                          0.0049
# HIV/AIDS                                                           -0.3205
# GDP                                                                -0.0000
# Population                                                          0.0000
# thinness  1-19 years                                                0.0257
# thinness 5-9 years                                                  0.0161
# Income composition of resources                                    -0.2250
# Schooling                                                           0.1464
# Country_Afghanistan                                            -3,118.6361
# Country_Albania                                                -3,102.6768
# Country_Algeria                                                -3,104.8620
# Country_Angola                                                 -3,124.6803
# Country_Antigua and Barbuda                                    -3,101.9321
# Country_Argentina                                              -3,103.1129
# Country_Armenia                                                -3,104.2291
# Country_Australia                                              -4,735.9942
# Country_Austria                                                -4,735.1760
# Country_Azerbaijan                                             -3,106.8502
# Country_Bahamas                                                -3,102.8174
# Country_Bahrain                                                -3,102.6356
# Country_Bangladesh                                             -3,108.6451
# Country_Barbados                                               -3,103.4041
# Country_Belarus                                                -3,107.3901
# Country_Belgium                                                -4,737.2501
# Country_Belize                                                 -3,108.0683
# Country_Benin                                                  -3,118.7265
# Country_Bhutan                                                 -3,111.9429
# Country_Bolivia (Plurinational State of)                       -3,109.8189
# Country_Bosnia and Herzegovina                                 -3,101.8489
# Country_Botswana                                               -3,115.5960
# Country_Brazil                                                 -3,105.5521
# Country_Brunei Darussalam                                      -3,101.9703
# Country_Bulgaria                                               -4,743.8312
# Country_Burkina Faso                                           -3,118.5534
# Country_Burundi                                                -3,119.9034
# Country_Cabo Verde                                             -3,104.9399
# Country_Cambodia                                               -3,113.1978
# Country_Cameroon                                               -3,119.6558
# Country_Canada                                                 -3,096.3329
# Country_Central African Republic                               -3,124.7070
# Country_Chad                                                   -3,123.1737
# Country_Chile                                                  -3,098.4947
# Country_China                                                  -3,106.3173
# Country_Colombia                                               -3,104.4802
# Country_Comoros                                                -3,115.7161
# Country_Congo                                                  -3,116.9543
# Country_Costa Rica                                             -3,099.2273
# Country_Croatia                                                -4,740.9325
# Country_Cuba                                                   -3,100.4625
# Country_Cyprus                                                 -4,737.2574
# Country_Czechia                                                -4,739.6539
# Country_Côte d'Ivoire                                          -3,124.9617
# Country_Democratic People's Republic of Korea                  -3,108.2967
# Country_Democratic Republic of the Congo                       -3,119.6015
# Country_Denmark                                                -4,738.2577
# Country_Djibouti                                               -3,114.4101
# Country_Dominican Republic                                     -3,104.4495
# Country_Ecuador                                                -3,102.9541
# Country_Egypt                                                  -3,106.6343
# Country_El Salvador                                            -3,105.8913
# Country_Equatorial Guinea                                      -3,119.2569
# Country_Eritrea                                                -3,116.1320
# Country_Estonia                                                -3,102.7653
# Country_Ethiopia                                               -3,113.3099
# Country_Fiji                                                   -3,109.3816
# Country_Finland                                                -3,097.6144
# Country_France                                                 -3,096.2995
# Country_Gabon                                                  -3,112.0945
# Country_Gambia                                                 -3,116.9958
# Country_Georgia                                                -3,103.9122
# Country_Germany                                                -4,736.5615
# Country_Ghana                                                  -3,115.1476
# Country_Greece                                                 -3,096.2049
# Country_Grenada                                                -3,104.6470
# Country_Guatemala                                              -3,105.1900
# Country_Guinea                                                 -3,119.6380
# Country_Guinea-Bissau                                          -3,120.0590
# Country_Guyana                                                 -3,111.1922
# Country_Haiti                                                  -3,115.9320
# Country_Honduras                                               -3,104.2370
# Country_Hungary                                                -4,743.0781
# Country_Iceland                                                -4,735.3156
# Country_India                                                  -3,113.5568
# Country_Indonesia                                              -3,111.4520
# Country_Iran (Islamic Republic of)                             -3,104.7174
# Country_Iraq                                                   -3,106.8142
# Country_Ireland                                                -4,736.8759
# Country_Israel                                                 -3,096.6687
# Country_Italy                                                  -4,734.9890
# Country_Jamaica                                                -3,103.0731
# Country_Japan                                                  -4,734.9475
# Country_Jordan                                                 -3,105.1783
# Country_Kazakhstan                                             -3,110.8386
# Country_Kenya                                                  -3,116.0082
# Country_Kiribati                                               -3,112.4973
# Country_Kuwait                                                 -3,103.9578
# Country_Kyrgyzstan                                             -3,108.2924
# Country_Lao People's Democratic Republic                       -3,114.6374
# Country_Latvia                                                 -4,742.8308
# Country_Lebanon                                                -3,103.8823
# Country_Lesotho                                                -3,120.7989
# Country_Liberia                                                -3,118.3955
# Country_Libya                                                  -3,106.4516
# Country_Lithuania                                              -4,744.2742
# Country_Luxembourg                                             -4,736.1138
# Country_Madagascar                                             -3,113.7265
# Country_Malawi                                                 -3,120.9684
# Country_Malaysia                                               -3,104.2770
# Country_Maldives                                               -3,103.2423
# Country_Mali                                                   -3,119.4300
# Country_Malta                                                  -4,736.5052
# Country_Mauritania                                             -3,114.2304
# Country_Mauritius                                              -3,105.3353
# Country_Mexico                                                 -3,102.4155
# Country_Micronesia (Federated States of)                       -3,108.9319
# Country_Mongolia                                               -3,111.7354
# Country_Montenegro                                             -3,103.1938
# Country_Morocco                                                -3,105.8667
# Country_Mozambique                                             -3,119.2245
# Country_Myanmar                                                -3,113.3830
# Country_Namibia                                                -3,112.5759
# Country_Nepal                                                  -3,111.6159
# Country_Netherlands                                            -4,736.3928
# Country_New Zealand                                            -4,736.6827
# Country_Nicaragua                                              -3,104.4871
# Country_Niger                                                  -3,116.7922
# Country_Nigeria                                                -3,111.2695
# Country_Norway                                                 -4,736.1597
# Country_Oman                                                   -3,103.3676
# Country_Pakistan                                               -3,115.4630
# Country_Panama                                                 -3,100.9286
# Country_Papua New Guinea                                       -3,114.7544
# Country_Paraguay                                               -3,104.8465
# Country_Peru                                                   -3,104.0542
# Country_Philippines                                            -3,110.0271
# Country_Poland                                                 -4,741.4508
# Country_Portugal                                               -4,736.8531
# Country_Qatar                                                  -3,100.7173
# Country_Republic of Korea                                      -3,096.7104
# Country_Republic of Moldova                                    -3,106.6956
# Country_Romania                                                -4,744.3018
# Country_Russian Federation                                     -3,109.7256
# Country_Rwanda                                                 -3,116.6805
# Country_Saint Lucia                                            -3,103.4432
# Country_Saint Vincent and the Grenadines                       -3,104.3772
# Country_Samoa                                                  -3,103.3617
# Country_Sao Tome and Principe                                  -3,112.0993
# Country_Saudi Arabia                                           -3,105.0988
# Country_Senegal                                                -3,113.8954
# Country_Serbia                                                 -3,103.5498
# Country_Seychelles                                             -3,105.0379
# Country_Sierra Leone                                           -3,128.8154
# Country_Singapore                                              -4,735.8996
# Country_Slovakia                                               -4,741.9924
# Country_Slovenia                                               -4,738.2774
# Country_Solomon Islands                                        -3,109.4571
# Country_Somalia                                                -3,121.9027
# Country_South Africa                                           -3,113.5498
# Country_South Sudan                                            -3,120.0062
# Country_Spain                                                  -4,735.0280
# Country_Sri Lanka                                              -3,105.5507
# Country_Sudan                                                  -3,113.8521
# Country_Suriname                                               -3,107.0014
# Country_Swaziland                                              -3,115.1331
# Country_Sweden                                                 -4,735.9409
# Country_Switzerland                                            -4,735.6366
# Country_Syrian Arab Republic                                   -3,107.3502
# Country_Tajikistan                                             -3,111.0112
# Country_Thailand                                               -3,104.9039
# Country_The former Yugoslav republic of Macedonia              -3,103.7801
# Country_Timor-Leste                                            -3,113.2309
# Country_Togo                                                   -3,119.2296
# Country_Tonga                                                  -3,105.1535
# Country_Trinidad and Tobago                                    -3,106.3645
# Country_Tunisia                                                -3,103.9508
# Country_Turkey                                                 -3,104.2819
# Country_Turkmenistan                                           -3,112.6774
# Country_Uganda                                                 -3,116.5002
# Country_Ukraine                                                -3,107.6263
# Country_United Arab Emirates                                   -3,102.2772
# Country_United Kingdom of Great Britain and Northern Ireland   -4,735.7826
# Country_United Republic of Tanzania                            -3,117.1871
# Country_United States of America                               -4,738.7516
# Country_Uruguay                                                -3,101.5756
# Country_Uzbekistan                                             -3,109.8623
# Country_Vanuatu                                                -3,105.9333
# Country_Venezuela (Bolivarian Republic of)                     -3,103.9872
# Country_Viet Nam                                               -3,103.4777
# Country_Yemen                                                  -3,113.1380
# Country_Zambia                                                 -3,118.4834
# Country_Zimbabwe                                               -3,117.8461
# Status_Developed                                                4,282.3211
# Status_Developing                                               2,642.9126
# intercept                                                           0.0000
# dtype: float64

# %% [markdown]
# > But coefficients have changed

# %%
ax = coeffs_noint[country_feats].sort_values().plot(kind='barh', figsize=(8,26))
ax.axvline(0)
ax.set(xlabel='Life Expectancy', title="Coefficients - Countries");

# %%
ax = coeffs_noint.drop(country_feats).sort_values().plot(kind='barh')#, figsize=(8,26))
ax.axvline(0)
ax.set(xlabel='Life Expectancy', title="Coefficients - Without Countries");

# %% [markdown]
# ## Model #3 - No Countries

# %%
# ### Train Test Split
## Make x and y variables
target = "Life expectancy"
drop_feats = ["Country"]

y = df[target].copy()
X = df.drop(columns=[target, *drop_feats]).copy()

## train-test-split with random state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=SEED)

## Make numeric preprocessing pipeline
num_sel = make_column_selector(dtype_include='number')
num_pipe = make_pipeline(SimpleImputer(strategy='mean'))


## Make categorical preprocessing pipeline
cat_sel = make_column_selector(dtype_include='object')
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(handle_unknown='ignore', sparse=False))

# %%
preprocessor.fit(X_train)
feature_names = preprocessor.get_feature_names_out()
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          columns=feature_names,
                         index=X_train.index)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          columns=feature_names,
                         index=X_test.index)

# %%
lin_reg= LinearRegression(fit_intercept=False)
lin_reg.fit(X_train_df,y_train)
evaluate_regression(lin_reg, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5e30">
#   <thead>
#     <tr>
#       <th id="T_f5e30_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_f5e30_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_f5e30_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_f5e30_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f5e30_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_f5e30_row0_col1" class="data row0 col1" >0.82</td>
#       <td id="T_f5e30_row0_col2" class="data row0 col2" >3.00</td>
#       <td id="T_f5e30_row0_col3" class="data row0 col3" >4.02</td>
#     </tr>
#     <tr>
#       <td id="T_f5e30_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_f5e30_row1_col1" class="data row1 col1" >0.82</td>
#       <td id="T_f5e30_row1_col2" class="data row1 col2" >3.06</td>
#       <td id="T_f5e30_row1_col3" class="data row1 col3" >4.12</td>
#     </tr>
#   </tbody>
# </table>

# %%
de.plot_residuals(lin_reg, X_test_df,y_test)

# %%
coeffs = get_coefficients(lin_reg)
coeffs
# Out:
# Year                              -0.0168
# Adult Mortality                   -0.0193
# infant deaths                      0.1070
# Alcohol                            0.0556
# percentage expenditure             0.0000
# Hepatitis B                       -0.0096
# Measles                           -0.0000
# BMI                                0.0391
# under-five deaths                 -0.0810
# Polio                              0.0250
# Total expenditure                  0.1062
# Diphtheria                         0.0377
# HIV/AIDS                          -0.4789
# GDP                                0.0000
# Population                         0.0000
# thinness  1-19 years              -0.0498
# thinness 5-9 years                -0.0265
# Income composition of resources    5.7370
# Schooling                          0.6857
# Status_Developed                  89.6930
# Status_Developing                 88.2086
# intercept                          0.0000
# dtype: float64

# %%
coeffs.sort_values().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Model 3: Dropping Categories with OneHotEncoder

# %% [markdown]
# ####  OneHotEncoder's Drop Argument

# %%
## make pipelines for categorical vs numeric data
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(drop='if_binary', sparse=False,
                                      ))
cat_pipe
# Out:
# Pipeline(steps=[('simpleimputer',
#                  SimpleImputer(fill_value='MISSING', strategy='constant')),
#                 ('onehotencoder',
#                  OneHotEncoder(drop='if_binary', sparse=False))])

# %%
num_pipe = make_pipeline(SimpleImputer(strategy='mean'))

## make the preprocessing column transformer
preprocessor = make_column_transformer((num_pipe, num_sel),
                                       (cat_pipe,cat_sel),
                                      verbose_feature_names_out=False)
preprocessor

preprocessor.fit(X_train)
feature_names = preprocessor.get_feature_names_out()

X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          columns=feature_names,
                         index=X_train.index)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          columns=feature_names,
                         index=X_test.index)
display(X_train_df.head())
# Out:
#            Year  Adult Mortality  ...  Schooling  Status_Developing
# 2414 2,010.0000         359.0000  ...     0.0000             1.0000
# 1576 2,009.0000         491.0000  ...     9.9000             1.0000
# 2559 2,009.0000         174.0000  ...    11.1000             1.0000
# 1524 2,013.0000         178.0000  ...    16.4000             0.0000
# 33   2,014.0000          11.0000  ...    14.4000             1.0000
#
# [5 rows x 20 columns]

# %%
lin_reg_drop = LinearRegression(fit_intercept=False)
lin_reg_drop.fit(X_train_df,y_train)
evaluate_regression(lin_reg_drop, X_train_df, y_train, 
                    X_test_df, y_test)

de.plot_residuals(lin_reg_drop, X_test_df,y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1fca4">
#   <thead>
#     <tr>
#       <th id="T_1fca4_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_1fca4_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_1fca4_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_1fca4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1fca4_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_1fca4_row0_col1" class="data row0 col1" >0.82</td>
#       <td id="T_1fca4_row0_col2" class="data row0 col2" >3.01</td>
#       <td id="T_1fca4_row0_col3" class="data row0 col3" >4.03</td>
#     </tr>
#     <tr>
#       <td id="T_1fca4_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_1fca4_row1_col1" class="data row1 col1" >0.82</td>
#       <td id="T_1fca4_row1_col2" class="data row1 col2" >3.05</td>
#       <td id="T_1fca4_row1_col3" class="data row1 col3" >4.12</td>
#     </tr>
#   </tbody>
# </table>

# %%
coeffs_dropped = get_coefficients(lin_reg_drop)


ax = coeffs_dropped.sort_values().plot(kind='barh')#, figsize=(8,26))
ax.axvline(0)
ax.set(xlabel='Life Expectancy', title="Coefficients - Without Countries");

# %% [markdown]
# > ***Q: What are the most positive coefficients? What are the most negative?***
#
# - Why does infant_deaths have a positive coefficient??

# %%
plot_df = pd.concat([X_train_df,y_train],axis=1)

# %%
sns.scatterplot(data=plot_df, x='infant deaths', y=target)
# Out:
# <AxesSubplot: xlabel='infant deaths', ylabel='Life expectancy'>

# %%
regplot_kws = dict(line_kws={'color':'red'},
                  scatter_kws={'ec':'white','lw':0.5})
sns.regplot(data=plot_df, x='infant deaths', y=target,**regplot_kws)
# Out:
# <AxesSubplot: xlabel='infant deaths', ylabel='Life expectancy'>

# %%
sns.regplot(data=plot_df, x='infant deaths', y=target,**regplot_kws,
           lowess=True)
# Out:
# <AxesSubplot: xlabel='infant deaths', ylabel='Life expectancy'>

# %% [markdown]
# > Feature is too complex for a simple linear regression. Let's try a random forest.

# %% [markdown]
# ## Feature Importance

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_reg = RandomForestRegressor()
rf_reg.fit(X_train_df,y_train)
evaluate_regression(rf_reg, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_38cf0">
#   <thead>
#     <tr>
#       <th id="T_38cf0_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_38cf0_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_38cf0_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_38cf0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38cf0_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_38cf0_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_38cf0_row0_col2" class="data row0 col2" >0.45</td>
#       <td id="T_38cf0_row0_col3" class="data row0 col3" >0.71</td>
#     </tr>
#     <tr>
#       <td id="T_38cf0_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_38cf0_row1_col1" class="data row1 col1" >0.97</td>
#       <td id="T_38cf0_row1_col2" class="data row1 col2" >1.11</td>
#       <td id="T_38cf0_row1_col3" class="data row1 col3" >1.75</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > Using the models .feature_names_in_

# %%
## Saving the coefficients
importances = pd.Series(rf_reg.feature_importances_, index= rf_reg.feature_names_in_)
importances
# Out:
# Year                              0.0076
# Adult Mortality                   0.1251
# infant deaths                     0.0070
# Alcohol                           0.0065
# percentage expenditure            0.0035
# Hepatitis B                       0.0024
# Measles                           0.0028
# BMI                               0.0114
# under-five deaths                 0.0151
# Polio                             0.0040
# Total expenditure                 0.0060
# Diphtheria                        0.0044
# HIV/AIDS                          0.5991
# GDP                               0.0042
# Population                        0.0032
# thinness  1-19 years              0.0059
# thinness 5-9 years                0.0096
# Income composition of resources   0.1636
# Schooling                         0.0185
# Status_Developing                 0.0001
# dtype: float64

# %%
ax = importances.sort_values().tail(20).plot(kind='barh')#,figsize=(6,4))
ax.axvline(0, color='k')
ax.set(title='Feature Importance - Decision Tree Regressor',ylabel="Feature Name",
      xlabel='Importance');

# %% [markdown]
# ## Using joblib to Save our Model, Data, and Objects

# %%
X_train.head()
# Out:
#       Year      Status  ...  Income composition of resources  Schooling
# 2414  2010  Developing  ...                           0.0000     0.0000
# 1576  2009  Developing  ...                           0.4150     9.9000
# 2559  2009  Developing  ...                           0.6010    11.1000
# 1524  2013   Developed  ...                           0.8340    16.4000
# 33    2014  Developing  ...                           0.7410    14.4000
#
# [5 rows x 20 columns]

# %%
evaluate_regression(lin_reg,X_train_df,y_train, X_test_df, y_test)
# Out:
# C:\Users\Elizabeth Spreng\anaconda3\envs\dojo-env\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - Status_Developed
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [54], line 1
# ----> 1 evaluate_regression(lin_reg,X_train_df,y_train, X_test_df, y_test)
#
# Cell In [17], line 6, in evaluate_regression(model, X_train, y_train, X_test, y_test, for_slides)
#       2 """Evaluates a scikit learn regression model using r-squared and RMSE
#       3 FOR SLIDES VERS DOES MULTIPLE PRINT STATEMENTS FOR VERTICAL DISPLAY OF INFO"""
#       5 ## Training Data
# ----> 6 y_pred_train = model.predict(X_train)
#       7 r2_train = metrics.r2_score(y_train, y_pred_train)
#       8 rmse_train = metrics.mean_squared_error(y_train, y_pred_train,
#       9                                         squared=False)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\sklearn\linear_model\_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# --> 369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\sklearn\base.py:600, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
# --> 600     self._check_n_features(X, reset=reset)
#     602 return out
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\sklearn\base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 20 features, but LinearRegression is expecting 21 features as input.

# %%
evaluate_regression(rf_reg,X_train_df,y_train, X_test_df, y_test)

# %%
import joblib, os

## creating a dictionary of all of the variables to save for later
export = {'X_train':X_train,
         'y_train':y_train,
         'X_test':X_test,
         'y_test':y_test,
          'preprocessor':preprocessor,
         'LinearRegression': lin_reg,
          'RandomForestRegressor':rf_reg
         }

# %%
folder = "Models/"
os.makedirs(folder, exist_ok=True)

# %%
fname = folder+'wk1-lect01-codealong.joblib'
joblib.dump(export, fname)

# %%
loaded = joblib.load(fname)
loaded.keys()

# %% [markdown]
# > We will continue working with this task and these models next class!

# %% [markdown]
# # *Teaser* Shap (For Regression)

# %%
# Import and init shap
import shap
shap.initjs()

# %%
# Take a sample of the training data
X_shap = shap.sample(X_train_df,nsamples = 500,random_state=SEED)
y_shap = y_train.loc[X_shap.index]

# Instantiate a Model Explainer with the model
explainer = shap.Explainer(rf_reg)

## Get shap values form the explainer
shap_values = explainer(X_shap,y_shap)

# %%
shap.summary_plot(shap_values, features = X_shap)
